# %% [markdown]
# beta_max parameters = 0.05, 0.03, 0.01
#
# isolated parameters = 0.0, 0.5, 0.9

# %%
from itertools import product

from simulation import run_simulation
from visualization import plot_results, combine_plot_results, create_video
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
history = run_simulation(infect_prob=0.4, isolated=0.0, save_frames=True)
# Out:
# Simulation complete. Final: S:0 I: 0 R:100 D:0

# %%
plot_results(history)

# %%
create_video(
    frames_dir="frames", output_file="covid_simulation.mp4", framerate=100
)
# Out:
# Video created successfully: covid_simulation.mp4
# True

# %%
infect_prob = [0.01, 0.03, 0.05]
isolated = [0.9, 0.5, 0.0]
history_results = {}
for ip, iso in list(product(infect_prob, isolated)):
    history_results[f"{ip}, {iso}"] = run_simulation(
        infect_prob=ip, isolated=iso
    )

# %%
combine_plot_results(history_results)
